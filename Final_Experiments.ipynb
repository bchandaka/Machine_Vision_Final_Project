# %%
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
from fusion_funcs import SensorFusion, load_data
# %matplotlib inline

# %% [markdown]
# # Experiment 1
# Date 2011-9-30, Drive 16, Notes: Straight Path
# <!-- 10 seconds -->

# %%
data = load_data('2011_09_26', '0001')

start_vec = np.array([0, 0, 0, 0])
kf1 = SensorFusion(start_vec, data)
kf1.setCutout(30,60)
kf1.setCutoutVar(10)
n_iter = -1
kf1.run_default(n_iter)
# Out:
#   0%|          | 0/107 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 107/107 [00:24<00:00,  4.39poses/s]

# %%
exp_name = 'Experiment 1: Straight Path'
kf1.plot_res(exp_name, 'exp1_10.png', False)
kf1.print_metrics()
# Out:
# KF Error: 2.036279876423427, VO Error: 10.680693030975236, Cutout Error: 13.84811499016325

# %%
data = load_data('2011_09_26', '0001')

start_vec = np.array([0, 0, 0, 0])
kf2 = SensorFusion(start_vec, data)
kf2.setCutout(30,60)
kf2.setCutoutVar(100)
n_iter = -1
kf2.run_default(n_iter)
# Out:
#   0%|          | 0/107 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 107/107 [00:23<00:00,  4.52poses/s]

# %%
exp_name = 'Experiment 1: Straight Path'
kf2.plot_res(exp_name, 'exp1_100.png', False)
kf2.print_metrics()
# Out:
# KF Error: 4.084399157767209, VO Error: 10.712532483048278, Cutout Error: 143.42542201149476

# %% [markdown]
# # Experiment 2
# Date 2011_10_03, Drive 27, Notes: Cutout over a curve

# %%
data = load_data('2011_10_03', '0027')

start_vec = np.array([0, 0, 0, 0])
kf3 = SensorFusion(start_vec, data)
kf3.setCutout(70,150)
kf3.setCutoutVar(10)
kf3.setDegOffset(30)
n_iter = 200
kf3.run_default(n_iter)
# Out:
#   0%|          | 0/200 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 200/200 [00:42<00:00,  4.73poses/s]

# %%
exp_name = 'Experiment 2: Turning'
kf3.plot_res(exp_name, 'exp2_10.png', False)
kf3.print_metrics()
# Out:
# KF Error: 2.369513897313992, VO Error: 7.068866161530744, Cutout Error: 11.17806255656275

# %%
start_vec = np.array([0, 0, 0, 0])
kf4 = SensorFusion(start_vec, data)
kf4.setCutout(70,150)
kf4.setCutoutVar(100)
kf4.setDegOffset(30)
n_iter = 200
kf4.run_default(n_iter)
# Out:
#   0%|          | 0/200 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 200/200 [00:36<00:00,  5.44poses/s]

# %%
exp_name = 'Experiment 2: Turning'
kf4.plot_res(exp_name, 'exp2_100.png', False)
kf4.print_metrics()
# Out:
# KF Error: 6.519196072979956, VO Error: 7.74545104298212, Cutout Error: 119.1366931903387

# %% [markdown]
# # Experiment 3
# Date 2011_10_03, Drive 27, Notes: Long Drive

# %%
data = load_data('2011_10_03', '0027')

start_vec = np.array([0, 0, 0, 0])
kf5 = SensorFusion(start_vec, data)
kf5.setCutout(200, 800)
kf5.setCutoutVar(10)
kf5.setDegOffset(30)
n_iter = 1100
kf5.run_default(n_iter)
# Out:
#   0%|          | 0/1100 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 1100/1100 [03:33<00:00,  5.15poses/s]

# %%
exp_name = 'Experiment 3: Long Drive'
kf5.plot_res(exp_name, 'exp3_10.png',False)
kf5.print_metrics()
# Out:
# KF Error: 3.628603849055577, VO Error: 35.77014394939457, Cutout Error: 12.36172863140888

# %%
data = load_data('2011_10_03', '0027')

start_vec = np.array([0, 0, 0, 0])
kf6 = SensorFusion(start_vec, data)
kf6.setCutout(200, 800)
kf6.setCutoutVar(100)
kf6.setDegOffset(30)
n_iter = 1100
kf6.run_default(n_iter)
# Out:
#   0%|          | 0/1100 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 1100/1100 [03:51<00:00,  4.75poses/s]

# %%
exp_name = 'Experiment 3: Long Drive'
kf6.plot_res(exp_name, 'exp3_100.png', False)
kf6.print_metrics()
# Out:
# KF Error: 20.77103012931652, VO Error: 36.77010710607335, Cutout Error: 125.45944081677618

# %% [markdown]
# # Experiment 4
# Same as experiment 2, but with low pass filter smoothing

# %%
data = load_data('2011_10_03', '0027')

start_vec = np.array([0, 0, 0, 0])
kf7 = SensorFusion(start_vec, data, use_smoothing=True)
kf7.setCutout(70,150)
kf7.setCutoutVar(10)
kf7.setDegOffset(30)

n_iter = 200
kf7.run_default(n_iter)
# Out:
#   0%|          | 0/200 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 200/200 [00:48<00:00,  4.11poses/s]

# %%
exp_name = 'Experiment 4: Smoothing'
kf7.plot_res(exp_name, 'exp4_10.png', False)
kf7.print_metrics()
# Out:
# KF Error: 16.99685886086731, VO Error: 7.994443656026287, Cutout Error: 12.449012078345817

# %%
data = load_data('2011_10_03', '0027')

start_vec = np.array([0, 0, 0, 0])
kf8 = SensorFusion(start_vec, data, use_smoothing=True)
kf8.setCutout(70,150)
kf8.setCutoutVar(100)
kf8.setDegOffset(30)

n_iter = 200
kf8.run_default(n_iter)
# Out:
#   0%|          | 0/200 [00:00<?, ?poses/s]c:\Users\Bhargav\coursework\cs498_m_vision\Machine_Vision_Final_Project\fusion_funcs.py:110: RuntimeWarning: invalid value encountered in true_divide
#   K = numerator/denominator
# 100%|██████████| 200/200 [00:45<00:00,  4.40poses/s]

# %%
exp_name = 'Experiment 4: Smoothing'
kf8.plot_res(exp_name, 'exp4_100.png', False)
kf8.print_metrics()
# Out:
# KF Error: 28.16460464586778, VO Error: 7.968018329273368, Cutout Error: 133.21974681767568
